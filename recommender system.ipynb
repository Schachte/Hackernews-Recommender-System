# %% [markdown]
# # Creating a Python-based recommender system for HackerNews posts
#
# In this notebook, we will walk through how to create a simple algorithm that will recommend the top 10 posts based on our interests. The steps required to do this look like the following:
#
# 1. Fetch N posts from the HN API and aggregate into a list in-memory
# 2. Cleanse the data by vectorizing the list and removing stop words
# 3. Create a matrix that follows the structure of TF-IDF (term frequency inverse document frequency)
# 4. From here, we can vectorize our query and compute the cosine similarity of our input against our model. We will sort and rank the most similar titles to find links of interest.

# %%
import requests

# Let's grab top HN stories so we can generate a similarity metric off title
response = requests.get('https://hacker-news.firebaseio.com/v0/topstories.json')
top_stories_ids = response.json()

# Define a function to fetch the title of a story given its ID
def fetch_title(story_id):
    response = requests.get(f'https://hacker-news.firebaseio.com/v0/item/{story_id}.json')
    story = response.json()
    return story['title']

# Fetch the titles of the top 200 stories and store them in an array
corpus = []
for story_id in top_stories_ids[:500]:
    title = fetch_title(story_id)
    corpus.append(title)

# %%
# We want to vectorize the words and remove common words like "of", "the", etc (stopwords)
vectorizer = TfidfVectorizer(stop_words='english')

# We won't define tfidf, but we're basically building a matrix of frequency counts
# and understanding their relative importance to other words within the document. 
# This format will be useful when using the vectors to compute cosine similarity
tfidf_matrix = vectorizer.fit_transform(corpus)

# Convert the sparse matrix to a pandas DataFrame for readability
df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out(), index=corpus)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

def find_most_similar(query, tfidf_matrix, corpus):
    """
    find_most_similar will leverage the vectors from above. We can take an input query 
    and compute the cosine similarity against all other vectors to rank the titles that are
    the most similar.
    """
    # Use the vectorizer to transform the query
    query_tfidf = vectorizer.transform([query])
    
    # Compute the cosine similarity between the query and all documents in the corpus
    cosine_similarities = np.dot(query_tfidf, tfidf_matrix.T).toarray()[0]
    
    # Sort the cosine similarities in descending order and return the indices of the most similar documents
    most_similar_indices = cosine_similarities.argsort()[::-1]
    
    # Print the most similar documents and their cosine similarity scores
    for i in range(len(most_similar_indices)):
        index = most_similar_indices[i]
        print(corpus[index])

# %%
import ipywidgets as widgets

# Add a small UI for funsies
query_box = widgets.Text(
    value='',
    placeholder='Type your query here',
    description='Query:',
    disabled=False
)

submit_button = widgets.Button(description="Submit")
def handle_submit(button):
    query = query_box.value
    find_most_similar(query, tfidf_matrix, corpus)

submit_button.on_click(handle_submit)

display(query_box)
display(submit_button)
# Out:
# Text(value='', description='Query:', placeholder='Type your query here')
# Button(description='Submit', style=ButtonStyle())
# Elon Musk Is Spiraling
# How long does Twitter have left?
# CEO of failed Silicon Valley Bank no longer a director at SF Fed
# Lakota helped a man preserve their language. He tried to sell it back to them
# Circle: SVB is 1 of 6 banking partners Circle uses for ~25% part of USDC in cash
# Show HN: structured-ripgrep – Ripgrep over structured data
# Forbe's 20th Best Bank Feb 2023: SVB Financial Group
# Digital Infinity
# Adventures in REPL Implementation
# Rspack: A fast Rust-based web bundler
# The Hyperreal
# Nearly 40% of software engineers will only work remotely
# Domain registrar Gandi gets bought out, removes free mailboxes
# VR Airplane Deicer Simulator
# There’s no such thing as a tree phylogenetically (2021)
# Show HN: PyBroker – Algotrading in Python with Machine Learning
# Stadia’s pivot to a cloud service has also been shut down
# Microbiologist Investigates After Her Beef Soup Turned Blue in the Fridge
# You Can Spend a Year on a Cruise Ship for Less Than Rent in Many Cities
# Dutch police collecting demonstrators' personal data on a large scale
# Smartphones and social media are destroying children’s mental health
# Systems design explains the world (2020)
# The AI hype bubble is the new crypto hype bubble
# Privatizing our digital identities
# How to make sense of intelligence leaks
# Show HN: APIRank.dev – We crawled and ranked public APIs from the internet
# Zig: The Modern Alternative to C
# An experimental beach barrier could be key to rebuilding eroding coastlines
# The Demise of Silicon Valley Bank
# Ask HN: Approaching 40 and trying to get a foothold into Software Engineering
# Telehealth startup Cerebral shared millions of patients’ data with advertisers
# The Big City; Aftermath of 40 Hours in an Elevator (1999)
# Taichi lang: High-performance parallel programming in Python
# Nvidia researchers setup an open source sensor network on Antartica
# Mistakes I made as an engineer, but had to become a manager to see
# Circle’s USDC Stablecoin Breaks Peg with $3.3B Stuck at Silicon Valley Bank
# Traute Lafrenz, Last Survivor of Anti-Hitler Group, Dies at 103
# Understanding Social Media Recommendation Algorithms
# Experimental Evidence on the Productivity Effects of Generative AI
# Trimming spaces from strings faster with SVE on an Amazon Graviton 3 processor
# Show HN: I built an autopilot for the lunar lander game
# Oxy is Cloudflare's Rust-based next generation proxy framework
# Visual ChatGPT
# The collapse of SVB exposes the largest crack in the economy
# Battery-free Game Boy (2020)
# Steel Threads are a powerful but obscure software design approach
# The Future of Perl
# Polls find strong support for nuclear in UK and Switzerland
# This week in KDE: Qt apps survive the Wayland compositor crashing
# Silicon Valley Bank failure could wipe out 'a whole generation of startups'
# Why Write?
# Meta is building a decentralized, text-based social network
# OpenHV – Open-Source Pixelart Science-Fiction Real-Time-Strategy Game
# What can I read to convince me I shouldn’t care about online privacy as much?
# South Korea government proposes increasing cap on weekly work hours
# Apple, Foxconn convince Indian state to loosen labor laws
# Ask HN: That happens to T-Bills when the Goverment locks up over debt ceiling?
# JavaScript and TypeScript features of the last 3 years
# Show HN: BBC “In Our Time”, categorised by Dewey Decimal, heavy lifting by GPT
# How computer vision is changing manufacturing in 2023
# Report from the California Department of Financial Protection on SVB [pdf]
# OpenXLA Is Available Now
# Stylized Water Shader
# Linux 6.4 Slated to Start Removing Old, Unused and Unmaintained Pcmcia Drivers
# Mullvad's campaign against EU chat control
# BlockFi has $227M in Silicon Valley Bank
# Silicon Valley Bank's Chief Risk Officer Joined 2 Months Ago
# Control Mario Kart 64 with your car over CAN bus (2016)
# FastKafka – A Free Open-Source Python Library for Building Kafka-Based Services
# Flux Keyboard
# These Shapes Are Topologically Equivalent
# SPA view transitions land in Chrome 111
# Single File Elixir Scripts
# A notebook is a human's best friend (2022)
# Emissions
# Show HN: ChatGPT-i18n – Translate websites' locale json files with AI assistance
# Even Wealthy Landlords Are Skipping Payments on Office Buildings
# Chemicals released during wildfires in Australia damaged the ozone layer
# Moderna to hire around 2k employees amid mRNA development push
# Upwelling: Combining real-time collaboration with version control for writers
# Audio engineer explains NPR's signature sound (2015)
# GarlicGPT – we hallucinate so you don't have to
# Facebook parent plans new job cuts that could match last year’s tally
# Sell-off in US bank stocks due to concerns over solvency of Silicon Valley Bank
# The False Promise of Chomskyism
# Core Views on AI Safety: When, Why, What, and How
# Startup Bank Had a Startup Bank Run
# Without us ‘there is no Google’: EU telcos pressure to pay for the internet
# Ignore the conspiracy theories: scientists know Covid-19 wasn't created in a lab
# Viruses revived from ancient permafrost can infect amoeba
# Augmented Reality Welding System
# The End of the Beginning (2020)
# Nord Stream: the tanker Minerva Julie spent 7 days idling near the attack site
# Audiences Grow Weary of Stories That Never End
# European Lisp Symposium 2023
# Show HN: JazzKeys.fyi – Tutorials for jazz and funk keyboard players
# California copes with heavy rain, flooding in latest 'atmospheric river' storm
# GigaGAN: Large-Scale GAN for Text-to-Image Synthesis
# The FBI Just Admitted It Bought US Location Data
# Bob Yannes Interview on the Sid/MOS6581 (C64 Synth Chip) 1996
# Ask HN: What are you working on to become a better programmer?
# Arch Linux Btrfs with hibernation in a swapfile
# Who’s Behind the NetWire Remote Access Trojan?
# Founders fund pulls money before SVB collapses
# Common Mac OS X Cursors
# Writing a Kubernetes Operator
# JPM bankers pull all-nighters to take on clients of Silicon Valley Bank
# Arnold Schwarzenegger’s Last Act
# China takes extreme measures to keep teens off TikTok
# Python Basics Onepager
# Silicon Valley Bank is the second-largest US bank failure in history
# Apple and Foxconn win permission for 12-hour shifts for women in India
# Silicon Valley Bank had no official chief risk officer for 8 months
# USDC depegs as Circle confirms $3.3B stuck with Silicon Valley Bank
# Show HN: Safe Data Changes in PostgreSQL
# Understanding computer networks by analogy (2000)
# Why Democracy Is Broken and How to Fix It
# HP outrages printer users with firmware update suddenly bricking third-party ink
# In Namibia, lions are king of the beach
# Google dusts off the Google+ playbook to fight ChatGPT
# An EV that removes CO2 from the air
# Bank run on Silicon Valley Bank
# How to Get Started with Dbt
# 30% of YC companies exposed through SVB can’t make payroll in the next 30 days
# Lisp-powered laptop with a battery life measured in years
# Why was there a run on Silicon Valley Bank?
# Discovering one bug after another in the UTF-8 decoding logic in OpenBSD
# The tech industry couldn't give Silicon Valley Bank 40 hours
# The Dot Essay (1923)
# USDC investor shells out $2M to receive $0.05 USDT trying to evade crash
# Silicon Valley Bank collapse is impacting many Indian startups
# Ahrefs Saved US$400M in 3 Years by Not Going to the Cloud
# Why I Use Old Hardware
# Picturing Pregnancy in Early Modern Europe
# The CoreDNS Cache Poisoning Conjecture
# Launch HN: Defer (YC W23) – Zero-infrastructure background jobs for Node.js
# Rewriting the CLI in Rust: Was It Worth It?
# High-value Amazon orders 'switched for cat food', say customers
# Hype on Hacker News and Silicon Valley (2016)
# An East African Kingdom Changed T Roosevelt and the Course of American Democracy
# Running LLaMA 7B on a 64GB M2 MacBook Pro with Llama.cpp
# Brazil seizing Flipper Zero shipments to prevent use in crime
# Allegations of Scientific Misconduct Mount as Physicist Makes His Biggest Claim
# Ask HN: What's the fastest and simplest way to prototype a web app in 2023?
# How to Live Without Google: Alternatives That Protect Your Privacy
# Has the generative AI pricing collapse already started?
# Ask HN: Is there any current “web of trust” social media?
# Giving the finger is a ‘God-given right’, Canadian judge rules
# Silicon Valley Bank's demise began with downgrade threat
# The semiautomated social network is coming
# “Clean Code, Horrible Performance” Discussion
# SVB Fallout Spreads Around the World as UK Firms Plead for Help
# SVB chief pressed lawmakers to weaken bank risk regulations
# Computer Science Degree Online – Bachelor of Science – WGU
# Wells Fargo clients report missing deposits as bank works on fix
# Outlaws at War in the Middle Ages
# Write Posix Shell
# IHP open source 130 nm BiCMOS PDK with 500 GHz fmax transistors
# Patterns is building a platform to abstract away data science busywork
# Isaac Asimov’s laws of robotics (1965) [video]
# A Suspiciously Criminal Portfolio Website
# ChatGPT's API is so good and cheap, it makes most text generating AI obsolete
# Not just SVB. There have been 562 bank failures since 2000
# Large language models are having their Stable Diffusion moment
# Coltrane: A music theory library with a command-line interface
# Did Air Pollution Influence Famous Impressionist Painters?
# How Climate Scenarios Lost Touch with Reality
# Wild macaques challenge the origin of intentional tool production
# What Is Synthetic Data? The Good, the Bad, and the Ugly
# On mindsets, mind shifts and wins
# The Internet’s Richest Fitness Resource Is a Site from 1999
# Repairing a tiny ribbon cable inside a 28 year old IBM ThinkPad 701c
# Patterns (YC S21) is hiring AI engineers
# Ivy League Schools Sure Look Like a Cartel
# Show HN: Find the most climate friendly meeting location
# Etsy Delays Seller Payouts Due to Run on Silicon Valley Bank
# Common Beginner Mistakes with React
# Box64 – Linux Userspace x86_64 Emulator Targeted at ARM64 Linux Devices
# Samsung “space zoom” moon shots are fake, and here is the proof
# Acard ANS-9010B 5.25-inch SATA x1-to-6-slot DDR2 RAM Disk (Deactivated)
# SVB Financial: Blow Up Risk (2022)
# Show HN: Browse and Generate AI Memes for Free
# Llama.cpp: Port of Facebook's LLaMA model in C/C++, with Apple Silicon support
# People with ADHD claim Adderall is ‘different’ now
# FDIC Takes over Silicon Valley Bank
# How to Insure Your Money When You’re Banking over $250K (2022)
# GNU Octave 8.1
# Wonder Studio: this AI-powered tool might be a preview of the future of VFX
# Disambiguating Arm, Arm ARM, ARMv9, ARM9, ARM64, AArch64, A64, A78, ...
# Kopia – incremental backups, encryption, compression, data deduplication
# ChatGPT-J: The Privacy-First, Self-Hosted Chatbot Built on GPT-J's Powerful AI
# A man says he accidentally unlocked and drove someone else’s Tesla using the app
# Adrian Schoolcraft: Police Officer Forcibly Committed for Reporting Corruption
# Roku filed an 8-K saying that of its $1.9B of cash, $487M is stuck at SVB
# $3.3B of the ~$40 billion of USDC reserves remain at SVB
# SVB depositors, investors tried to pull $42B Thursday
# How do you take efficient notes?
# Avoiding visible texture repetition (2015)
# Show HN: ReplGPT.jl, a ChatGPT shell mode for Julia
# Cobble_stone – The texture of your childhood (2021)
# Who reads your email?
# Carp lang: statically typed Lisp, no GC
# US seizes control of SVB in second bank failure in a week
# Debconf's questions, or whiptail, doesn't always work in xterms
# I use cheap notebooks
# The Quest for Netflix on Asahi Linux
# Emergency bridge loan for SVB customers
# Secretive: Store SSH Keys in the Secure Enclave
# Growing crops under solar panels
# SF payroll firm Rippling has to delay payouts after Silicon Valley Bank collapse
# Rodin Diffusion: A Generative Model for Sculpting 3D Digital Avatars
# Elektro, the Moto-Man, Is a Friendly “Frankenstein” (1939)
# Black Hole Electron
# What does Silicon Valley Bank’s collapse mean for the financial system?
# I Asked Leading Covid Scientists, Off the Record, About the Lab Leak Theory
# Age Verification Mandates Would Undermine Anonymity Online
# List of Largest US Bank Failures
# Kiviaq – Greenland’s misunderstood winter delicacy
# Julia 1.9 precompilation will be a turning point
# The Coffeeshop Fallacy (2011)
# Silicon Valley Bank staff offered 45 days of work at 1.5 times pay
# The History of LZ Compression
# First Republic Bank files 8-K – Tech only 4% of total deposits; no sector >9%
# The Crafty Logic That Accompanies Dementia
# Document Production: Visual or Logical? (1987) [pdf]
# So You Want to Turn an Office Building into a Home?
# Version SAT (2016)
# Security robots are at Philly Lowe’s stores. Some have nicknamed them snitchBOTs
# In California, a Race to Capture the Water Before It Escapes
# What Is Systems Programming, Really? (2018)
# Evidence of a predictive coding hierarchy in the human brain listening to speech
# Spars Code
# 129-year-old vessel still tethered to lifeboat found on floor of Lake Huron
# Launch HN: Second (YC W23) – AI bots that add features to web apps
# A SVB short seller explains red flags he saw months ago
# Saving 4M books from landfill
# Stablecoin USDC breaks dollar peg after revealing $3.3B SVB exposure
# How to Yubikey
# First Complete Wiring Map of Neurons in Insect Brain
# The Basics of Arm64 Assembly
# What a good debugger can do
# Load 'em up and throw 'em under the bus
# SVB was the main bank for two of our companies, my personal savings and mortgage
# Startups that use Silicon Valley Bank are freaking out over payroll
# Modern Symbolics Lisp Machine Keyboard Replica: Keymacs A620N-88
# Serverless maps at 1/700 the cost of Google Maps API
# Shane Pitman, leader of the warez group Razor 1911: life after prison (2005)
# Coinbase suspending USDC:USD conversions over the weekend
# How to start a rocket engine
# WhatsApp would not remove end-to-end encryption for UK law, says chief
# I Bought a High-Mileage Electric Car with a Bad Battery
# Tesla steering wheel falls off while driving
# Python 3.11 is much faster, but Pyston and PyPy still show advantages
# Mastodon Link Debugger
# When to Comment That Code
# Windows Steam Games on ARM SBC via Box86, Proton and Unlimited Patience
# GPT-4 is coming next week – and it will be multimodal, says Microsoft Germany
# Google internally developed chatbots like ChatGPT years ago
# Bing AI can play chess
# Meta explores decentralized social network app for text updates
# The Nord Stream Andromeda Story: What We Know and What We Don’t
# GPT-4 is coming next week – and it will be multimodal, says Microsoft Germany
# Rust 1.68.0
# Feds suspect Tesla using automated system in firetruck crash
# On Chomsky and the Two Cultures of Statistical Learning
# US Executive Branch Proposes Capital Gains start at 10%, up to 39.6%
# Ricky Gervais' Twitter account has been hacked
# Discord will possibly record video and voice calls, channels, and screen shares
# Meta looking at creating Twitter rival
# China’s ChatGPT Black Market Is Thriving
# Google, Meta hired talent to do 'fake work'
# If you're so good, why aren't you making 600k at BigTech?
# Catholic group spent millions on app data that tracked gay priests
# Stripe increases prices for US businesses starting June first, 2023
# Linus Torvalds on Word-Wrapping Git Commit Messages
# US Air Force Moving Fast on AI-Piloted Fighter Jets
# Were React hooks a mistake?
# Laptop Brands with GNU/Linux Preinstalled
# Apple's plan to saturate all ages with iPhone, iPad and Mac is working
# “To understand a sentence is to know the conditions under which it is true.”
# Ryzen 7950X3D review: An expensive but efficient 16-core CPU
# Bitwarden flaw can let hackers steal passwords using iframes
# Rare 'snow tornado' spotted by Shetland crofter
# Ask HN: Why are Windows and macOS upgrades so terribly slow compared to Linux?
# Silvergate Bank to begin voluntary liquidation
# Sigmoid Colon: The biologically inspired activation function
# An Update on Dianna's Health (Physics Girl) [video]
# The US Air Force Is Moving Fast on AI-Piloted Fighter Jets
# Anatomy of a Bank Takeover (2009)
# Universities became giant piggy banks for hedge-fund billionaires
# Spotify Reaches 500M MAUs
# 5.2% pay raise proposal for federal employees in 2024
# Show HN: DemandHunt – Make something people want
# People Were Unwittingly Implanted with Fake Devices in Medical Scam
# Ask HN: Accused of acting sexist. What do do?
# Awash in Asphalt, Cities Rethink Their Parking Needs
# SVB Explanation by Jonwu_ on Twitter
# Visa, Mastercard Pause Work on Code Aimed at Tracking Gun Purchases
# DuckDuckGo Launches DuckAssist
# GPT 4 coming next week
# Ask HN: How a non dev ops host things to the world?
# EU 8K TV ban goes into effect – here’s how Samsung got around it
# Electricity from thin air: enzyme to extract energy from hydrogen in the air
# How do I find useful content on the internet in 2023?
# FTC says online counseling service BetterHelp broke privacy promises
# How to brazenly steal $100B from Medicare and Medicaid
# GM offers buyouts to ‘majority’ of U.S. salaried workers
# Amstrad Emailer, the UK’s first smartphone
# Effortless Performance Improvements in C++: std:vector
# Santos allegedly masterminded 2017 ATM fraud
# Ask HN: Best document storage solution in 2023
# The Surprising Effects of Remote Work
# Xero plans to cut up to 800 jobs
# Silvergate shutting down operations and liquidating bank
# US man puts phone on drone to send rescue message
# The SSD Edition: 2022 Drive Stats Review
# Gender dysphoria is rising – and so is professional disagreement
# Crypto bank Silvergate to shut down in face of market turmoil
# Is the Cell Really a Machine? (2019)
# Why π^π^π^π could be an integer (for all we know) [video] (2021)
# Bill Ackman: The gov't has about 48h to fix a-soon-to-be-irreversible mistake
# Today’s startups should terrify you
# Symbol Grounding Problem
# Filmora revokes lifetime subscriptions [video]
# Researchers Say They've Created Superconductors at Room Temperature
# The “heat death” hypothesis might not hold
# Laid-off Twitter software engineer calls job market 'hot garbage'
# Raising the bar for software security: GitHub 2FA begins March 13
# New estimate for high-speed rail puts California train $100B in the red
# Is there an end in sight for Oakland’s ransomware crisis?
# Don’t Aim for Perfection
# Twitter just let its privacy- and security-protecting Tor service expire
# Does SVBs disaster mean I should diversify my startups funding across many banks
# Iterators and Iterables in Python: Run Efficient Iterations – Real Python
# Breakthrough as eggs made from male mice cells
# Spotify’s new design is part TikTok, part Instagram, and part YouTube
# 1U AMD Ryzen 7000 Server: ASRock Rack 1U4LW-B650/2L2T Review
# LLMs are not going to destroy the human race
# China trounces U.S. in AI research output and quality
# Update to Kagi Search Pricing
# ‘Pan-variant’ Covid vaccine may defang future strains thanks to machine learning
# Tesla was likely on autopilot in deadly fire truck crash in Bay Area, feds say
# Musk Is Planning a Texas Utopia–His Own Town
# Train derails on way to load nuclear waste
# How to approach titling for early engineering hires?
# Some VC firms are urging founders to pull money from Silicon Valley Bank
# One Guy’s Car Blog Became a $1B Marketplace
# German prosecutors searched boat Nord Stream saboteurs may have used
# The trend of rising IQ in younger generations appears to be reversing
# Scientists Have Discovered an Enzyme That Converts Air into Electricity
# Ask HN: Physical whiteboard interviews coming back due to ChatGPT/Copilot/LLM?
# Meta mulls a Twitter competitor that will be interoperable with Mastodon
# Rotating Sandwiches – That's It
# At Silicon Valley Bank Risky “Tech” Startups Are Lucrative Business (2015)
# Stripe – Pricing changes for US businesses starting June 1, 2023
# New Update 2 of AmigaOS 3.2 available for download now
# I am a model and I know that AI will eventually take my job (2020)
# Taibbi: Media is spineless media for ignoring FTC’s demand to reveal journalists
# Why the Myers-Briggs test is meaningless
# Which is worse when working on production databases? Being drunk or tired?
# Door-in-the-Face Technique
# Meta mulls a Twitter competitor that will be interoperable with Mastodon
# I make $156,000 a year at Twitter and have done nothing
# Room-temperature superconductor works at lower pressures
# How a social network falls apart
# The Reliable Web App Pattern for .NET
# Discord testing ChatGPT powered bot
# ChatGPT is now available in Azure OpenAI Service
# The Big Con: How the Consulting Industry Weakens Our Businesses, Infantilizes
# Orion’s Heat Shield Looked Wonky After Artemis 1 Moon Mission, NASA Says
# Sam Altman invested $180M into a company trying to delay death
# Joint Trilateral Statement by Saudi Arabia, Iran and People’s Republic of China
# Losing Signal
# Ask HN: Use RAM sticks as SATA drives
# The Alarming Rise of India’s Pay-to-Breathe Industry
# Scientists create mice with two fathers after making eggs from male cells
# What does "Copy clean link" mean?
# The familiar story of the 17th century told through unfamiliar voices
# TikTok Whistleblower Tells Congress Data Protections Don't Stop Chinese Access
# SVB Chief Sold $3.6M in Stock Days Before Bank’s Failure
# Curl 25 Years Online Celebration
# Ask HN: How is the SVB situation affecting your startup?
# Tesla puts a ‘dummy’ camera in its new vehicles
# Overhead of Python asyncio tasks
# USDC Loses Peg to the Dollar
# A rant on web font licenses
# U.S. solar and storage manufacturing jobs expected to grow to 115,000 by 2030
# U.S. deficit grows to $262B in February (+21% YoY) as tax refunds surge
# Mathematician James Glimm may have solved the Poincare Conjecture
# Tricks from a marketers handbook: identifying enterprise buying intent
# GDevelop: An open-source, cross-platform, free, and easy game-making app
# Companies scramble to meet payroll, pay bills after SVB’s Swift failure
# Show HN: A Datadog for Datadog
# Amazon owe me £53,000 and refuse to trace the funds
# ChatGPT is now finding bugs in databases
# SVB in talks to sell itself after attempts to raise capital fail
# Yyvette's Bridal
# A Japanese Mega-Kitchen Prepares Thousands of School Lunches Everyday
# Some Cities Are More Doomed Than Others – Peter Thiel and Dave Rubin
# Ahrefs saved $400m in 3 years by not going to the cloud
# London fears for its future as companies defect to Wall Street
# U.S. Imports from China Continue Cratering
# Twitter’s $42k-per-month API prices out nearly everyone
# Shein, Temu in fierce fight over US market for $10 dresses
# Show HN: Discontent – Extension to fight garbage content on the web
# If you work at Dreamhost, can you help us?
# Nigeria is first African nation to ratify open banking operational regulations
# Upwelling – Realtime collaboration with version control
# SVBUK Taken in to Insolvency
# Promoting Palaeontology Across Sudan
# Adidas grapples with $1.3B in unsold Yeezy sneakers
# Before the collapse of Silicon Valley Bank,executives sold a lot of their shares
# After Silicon Valley Bank fails, tech startups race to meet payroll
# Letter to Pixar President Ed Catmull [pdf] (2004)
# $22B project to provide 8% of UK energy via undersea cable from North Africa
# DontBreakDebian: Advice for New Users on Not Breaking Their Debian System
# USDC Down ~10%
# Belgium bans TikTok from federal government work phones
# NYC man freed after 18 years, wrong photo led to murder conviction
# Nord Stream investigations: Traces lead to Ukraine
# E-Trikes Are Coming to Rescue the Aging Suburbs
# Leveraging Rust and the GPU to render user interfaces at 120 FPS
# Palm-E: An embodied multimodal language model
# Cats and dogs – Screen FPS – Dogs require 70fps and cats about 100
# Bing crossed 100M daily active users for the first time with Bing Chat AI
# Code coverage for Go integration tests
# Ahrefs Saved US$400M in 3 Years by Not Going to the Cloud
# Scientists Discover Enzyme That Turns Air into Electricity
# Waiting for Brando: A disastrous 1961 film production of the Iliad
# Ask HN: Is there anyone here making music?
# Your Bank Has Failed (2009)
# NGAD Fighters, 1k Advanced Drones in USAF’s Future Plans
# Internet Story (2011) [video]
# When Debug Symbols Get Large
# KGB Defector Yuri Bezmenov 1985 Interview – Idealogical Subversion
# Show HN: Lofi, a Tiny Spotify Player
# YouTuber must pay $40K in attorneys’ fees for daft “reverse censorship” suit
# Full screen triangle optimization
# A Pixel Is Not a Little Square (1995) [pdf]
# Grade inflation lures parents to new locations, inflating real estate prices
# Short Sellers Make $500M on SVB’s Demise. Collecting Won’t Be Easy
# How platform integration in Qt/KDE apps works
# First Republic Hit by Silicon Valley Bank Failure
# French union CGT cut power to Amazon facility to protest Macron's pension reform
# OOP: A practical alternative to Inheritance
# New Raspberry Pi Global Shutter Camera for Machine Vision and More
# Ask HN: Guidance on writing a source to source compiler (transpiler)
# Why are so many guys obsessed with Master and Commander?
# Blind: Next Bank to Collapse?
# Silicon Valley Bank down by over 50% today
# Personal information of members of Congress exposed in health data breach
# Discord may record video and voice calls
# Rippling historically relied on SVB for payments rails for payroll
# Ask HN: How do you find time for everything in life?
# Dynamic host configuration, please (OpenBSD)
# Do Attackers Attack Printers?
# Building a city optimized for bikes is a choice
# OSS maintainers are losing GitHub sponsors due to loss of PayPal support
# ‘It’s Draining Men’: When Citizens Name Municipal Fixtures, the Puns Flow Freely
# Show HN: An ORM that understands your business logic
# Show HN: I indexed 1.3m+ email newsletters
# Kids Are Not Okay
# DNS Resolver Quad9 Loses Global Pirate Site Blocking Case Against Sony
# Startup lender Silicon Valley Bank to sell stock to cope with cash burn
# Has the generative AI pricing collapse already started?
# The first wiring map of an insect's brain hints at incredible complexity
# I hate how much I enjoy the Remarkable 2’s $199 keyboard case
# SVB is experiencing a bank run
# New Twitter API pricing starts at $42,000 per month
# SVB’s UK Business to Be Declared Insolvent by Bank of England
# Are road speed limits based on safety?
# The future of TV is up in the air
# The 24 Hour “Do Nothing” Challenge
# Loom: Cache configuration change leading to account vulnerability
# Microsoft Bing hits 100M active users in bid to grab share from Google
# Roku says it could lose 25 percent of its cash after Silicon Valley Bank fails
# Meta's CFO Susan Li says some projects and teams will 'wind down'
# Ask HN: Where are all the tech company closures?
# Ask HN: What’s the optimal approach for KNN (K- Nearest Neighbor)?
# Show HN: Homepage.gallery – Find your web design inspiration
# Ira Glass on Storytelling (2008)
# Stripe Is on Track to Turn a Profit with $1T in Payment Volume
# Show HN: Send an AI Generated Physical Letter to Congress in Seconds
# Ask HN: Is there a good alternative for a local ChatGPT
# Permanent daylight saving time? Where efforts to ‘lock the clocks’ stand
# It’s Not What You Say, It’s How You Say It: Encrypted Messaging as a DOJ Weapon
# Ask HN: What Rust topics do you suggest for a Rust 101 teaching guide?
# Silicon Valley Bank drops another 60%, weighs on the bank sector again
# Banks lose billions in value after tech lender SVB stumbles
# Getting Past “Ampersand-Driven Development” in Rust
# Banks tumble as SVB ignites capitalization fears
# Disclosure: Supervisor security vulnerability
# Apple launches its new classical music streaming app for pre-order
# JDK 20 and JDK 21: What we know so far
# Multimodal GPT-4 to be released next week
# Running Stable Diffusion fully in browser with WebGPU
# Bay Area congressman calls for Sillcon Valley Bank bailout
# Ask HN: How have you applied AI in your life, work or hobbies?
# The AI Seinfeld Show 'Nothing, Forever' Is Back on Twitch
# Map of an Insect’s Brain
